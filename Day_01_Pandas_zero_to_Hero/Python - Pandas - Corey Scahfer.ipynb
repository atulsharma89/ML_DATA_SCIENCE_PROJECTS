# %% [markdown]
# # Python Pandas Tutorial (Part 1): Getting Started with Data Analysis - Installation and Loading Data

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# dataframe is just rows and columns

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
#number of rows and columns
#shape is an attribute and not mthod so we dont put ()

df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

schema_df.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %% [markdown]
# # Python Pandas Tutorial (Part 2): DataFrame and Series Basics - Selecting Rows and Columns

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
person = {"first": "Chorey",
          "last": "Schafer",
          "email": "ChoreyMSchafer@gmail.com"
    }

# %%
person ={"first": ["Chorey"],
          "last": ["Schafer"],
          "email": ["ChoreyMSchafer@gmail.com"]
    
}

# %%
person ={"first": ["Chorey","Jane",'John'],
          "last": ["Schafer","Doe","Doe"],
          "email": ["ChoreyMSchafer@gmail.com","JaneDoe@email.com","JohnDoe@email.com"]
    
}

# %%
#accessing content of dictionary
person["email"]
# Out:
# ['ChoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
import pandas as pd

df1 = pd.DataFrame(person)

# %%
df1.head()
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
#accessing information from dataframe

#accessing single value

df1['email']
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# 2           JohnDoe@email.com
# Name: email, dtype: object

# %%
df1["email"]
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# 2           JohnDoe@email.com
# Name: email, dtype: object

# %%
type(df1["email"])
# Out:
# pandas.core.series.Series

# %%
#series is list of data
#series is a 1 dimesion of data
#df is rows and columns
#series is rows of single column
#series is single column of rows
#df is containers of multiple series

# %%
df1.email
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# 2           JohnDoe@email.com
# Name: email, dtype: object

# %%
#accessing multiple columsn

df1[["first","last"]]
# Out:
#     first     last
# 0  Chorey  Schafer
# 1    Jane      Doe
# 2    John      Doe

# %%
type(df1[["first","last"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#getting rows using loc and iloc

#iloc: allows us to access rows using integer location

# %%
df1.iloc[0]
#returns series that has the values of first row of data
# Out:
# first                      Chorey
# last                      Schafer
# email    ChoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
df1.iloc[[0,1]]
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com

# %%
df1.iloc[[0,1],2]
#iteger location
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# Name: email, dtype: object

# %%
df1.loc[[0,1],"email"]
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# Name: email, dtype: object

# %%
df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
df1.loc[0]
# Out:
# first                      Chorey
# last                      Schafer
# email    ChoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
df1.loc[[0,1]]
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com

# %%
df1.loc[[0,1],"email"]
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# Name: email, dtype: object

# %%
df1.loc[[0,1],["last","email"]]
# Out:
#       last                     email
# 0  Schafer  ChoreyMSchafer@gmail.com
# 1      Doe         JaneDoe@email.com

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
#slicing

df.loc[0:3,'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# Name: Hobbyist, dtype: object

# %%
df.loc[0:3,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time

# %% [markdown]
# # Python Pandas Tutorial (Part 3): Indexes - How to Set, Reset, and Use Indexes

# %%
df1.head()
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
df1["email"]
# Out:
# 0    ChoreyMSchafer@gmail.com
# 1           JaneDoe@email.com
# 2           JohnDoe@email.com
# Name: email, dtype: object

# %%
df1.set_index('email')
# Out:
#                            first     last
# email
# ChoreyMSchafer@gmail.com  Chorey  Schafer
# JaneDoe@email.com           Jane      Doe
# JohnDoe@email.com           John      Doe

# %%
df1.head()
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
df1.set_index('email', inplace=True)

# %%
df1.head()
# Out:
#                            first     last
# email
# ChoreyMSchafer@gmail.com  Chorey  Schafer
# JaneDoe@email.com           Jane      Doe
# JohnDoe@email.com           John      Doe

# %%
df1.index
# Out:
# Index(['ChoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df1.loc['JaneDoe@email.com']
# Out:
# first    Jane
# last      Doe
# Name: JaneDoe@email.com, dtype: object

# %%
df1.loc['JaneDoe@email.com',"last"]
# Out:
# 'Doe'

# %%
# df1.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# ...

# %%
df1.iloc[0]
# Out:
# first     Chorey
# last     Schafer
# Name: ChoreyMSchafer@gmail.com, dtype: object

# %%
#resetting index

df1.reset_index(inplace=True)

df1.head()
# Out:
#    index                     email   first     last
# 0      0  ChoreyMSchafer@gmail.com  Chorey  Schafer
# 1      1         JaneDoe@email.com    Jane      Doe
# 2      2         JohnDoe@email.com    John      Doe

# %%
df1.head()
# Out:
#    index                     email   first     last
# 0      0  ChoreyMSchafer@gmail.com  Chorey  Schafer
# 1      1         JaneDoe@email.com    Jane      Doe
# 2      2         JohnDoe@email.com    John      Doe

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#df.set_index('Respondent', inplace=True)

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')

df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv',index_col='Column')

schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# # Python Pandas Tutorial (Part 4): Filtering - Using Conditionals to Filter Rows and Columns

# %%
df1.head()
# Out:
#    index                     email   first     last
# 0      0  ChoreyMSchafer@gmail.com  Chorey  Schafer
# 1      1         JaneDoe@email.com    Jane      Doe
# 2      2         JohnDoe@email.com    John      Doe

# %%
df1 = pd.DataFrame(person)

df1.head()
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
df1['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
#we got series with bunch of true false values

filt = (df1['last'] == 'Doe')

filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df1[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df1[df1['last']=='Doe']
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df1.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df1.loc[filt,'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df1['last'] == 'Doe') & (df1['first'] == 'John')

df1.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df1['last'] == 'Doe') | (df1['first'] == 'John')

df1.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
#getting complete opposite of filter 

df1.loc[~filt, 'email']
# Out:
# 0    ChoreyMSchafer@gmail.com
# Name: email, dtype: object

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
#data who is making salary greater than certain amaount

high_salary = (df['ConvertedComp'] > 70000)

df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[high_salary,['Country', 'LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']

filt = df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
#check if python is within the string

filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# # Python Pandas Tutorial (Part 5): Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.columns = ['first_name', 'last_name', 'email']

df1.head()
# Out:
#   first_name last_name                     email
# 0     Chorey   Schafer  ChoreyMSchafer@gmail.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
#using list comprehensions

df1.columns = [x.upper() for x in df1.columns]

df1
# Out:
#   FIRST_NAME LAST_NAME                     EMAIL
# 0     Chorey   Schafer  ChoreyMSchafer@gmail.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
df1.columns = df1.columns.str.replace('_',' ')

df1
# Out:
#   FIRST NAME LAST NAME                     EMAIL
# 0     Chorey   Schafer  ChoreyMSchafer@gmail.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
df1.columns = [x.lower() for x in df1.columns]

df1
# Out:
#   first name last name                     email
# 0     Chorey   Schafer  ChoreyMSchafer@gmail.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
df1.columns = df1.columns.str.replace(' ', '_')

df1
# Out:
#   first_name last_name                     email
# 0     Chorey   Schafer  ChoreyMSchafer@gmail.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
df1.rename(columns={'first_name':'first','last_name':'last'}, inplace = True)

#df1

# %%
df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
df1.loc[2]
# Out:
# first                 John
# last                   Doe
# email    JohnDoe@email.com
# Name: 2, dtype: object

# %%
df1.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John    Smith       JohnSmith@email.com

# %%
df1.loc[2,['last','email']]
# Out:
# last                   Smith
# email    JohnSmith@email.com
# Name: 2, dtype: object

# %%
df1.loc[2,['last','email']] = ['Doe', 'JohnDoe@email.com']

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
df1.loc[2,'last'] = 'Smith'

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John    Smith         JohnDoe@email.com

# %%
df1.at[2,'last'] = 'Doe'

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
filt = (df1['email']== 'JohnDoe@email.com')

df1[filt]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@email.com

# %%
df1[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
df1[filt]['last'] = 'Smith'

df1
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/1597728059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[filt]['last'] = 'Smith'
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John      Doe         JohnDoe@email.com

# %%
#df1[filt]['last'] = 'Smith'

df1.loc[filt, 'last'] = 'Smith'

df1
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/177521437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[filt]['last'] = 'Smith'
#     first     last                     email
# 0  Chorey  Schafer  ChoreyMSchafer@gmail.com
# 1    Jane      Doe         JaneDoe@email.com
# 2    John    Smith         JohnDoe@email.com

# %%
#changing multiple rows at once
df1['email'] = df1['email'].str.lower()

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  choreymschafer@gmail.com
# 1    Jane      Doe         janedoe@email.com
# 2    John    Smith         johndoe@email.com

# %%
#apply
#map
#applymap
#replace

# %%
# apply : apply is used toc all function on values
#it can be either applied on dataframe or a series objects
#if applied on series than it can be applied to each value of the series

# %% [markdown]
# **Apply on Series**

# %%
df1['email'].apply(len)
# Out:
# 0    24
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df1['email'].apply(update_email)
# Out:
# 0    CHOREYMSCHAFER@GMAIL.COM
# 1           JANEDOE@EMAIL.COM
# 2           JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df1['email'] = df1['email'].apply(update_email)

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  CHOREYMSCHAFER@GMAIL.COM
# 1    Jane      Doe         JANEDOE@EMAIL.COM
# 2    John    Smith         JOHNDOE@EMAIL.COM

# %%
df1['email'] = df1['email'].apply(lambda x : x.lower())

df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  choreymschafer@gmail.com
# 1    Jane      Doe         janedoe@email.com
# 2    John    Smith         johndoe@email.com

# %% [markdown]
# **Apply on Dataframe**

# %%
df1['email'].apply(len)
# Out:
# 0    24
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df1.apply(len)

# its not applying len function in every value in df
#its applying len function to each series in df specially each column
# first has 3 values
# last has 3 values
# email has 3 values
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df1['email'])
# Out:
# 3

# %%
df1.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df1.apply(pd.Series.min)
# Out:
# first                      Chorey
# last                          Doe
# email    choreymschafer@gmail.com
# dtype: object

# %%
#lambda works on series objects

df1.apply(lambda x:x.min())
# Out:
# first                      Chorey
# last                          Doe
# email    choreymschafer@gmail.com
# dtype: object

# %% [markdown]
# **ApplyMap only works with dataframe --> this can be used to apply a function on each individual values**

# %%
df1.applymap(len)
# Out:
#    first  last  email
# 0      6     7     24
# 1      4     3     17
# 2      4     5     17

# %%
df1.applymap(str.lower)
# Out:
#     first     last                     email
# 0  chorey  schafer  choreymschafer@gmail.com
# 1    jane      doe         janedoe@email.com
# 2    john    smith         johndoe@email.com

# %% [markdown]
# **Map method only works on series**
#
# **Substituting each values in a series with another value**

# %%
df1
# Out:
#     first     last                     email
# 0  Chorey  Schafer  choreymschafer@gmail.com
# 1    Jane      Doe         janedoe@email.com
# 2    John    Smith         johndoe@email.com

# %%
df1['first'].map({'Chorey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df1['first'].replace({'Chorey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df1['first'] = df1['first'].replace({'Chorey': 'Chris', 'Jane': 'Mary'})

df1
# Out:
#    first     last                     email
# 0  Chris  Schafer  choreymschafer@gmail.com
# 1   Mary      Doe         janedoe@email.com
# 2   John    Smith         johndoe@email.com

# %%
#renaming columns

df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace = True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

df.head()

#anything apart from yes or no will be repalced with NaN
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
#if we want to replace yes with True and No with False and let all other values untocuhed then we can use replace function

# %% [markdown]
# # Python Pandas Tutorial (Part 6): Add/Remove Rows and Columns From DataFrames

# %% [markdown]
# **Adding columns**

# %%
df1
# Out:
#    first     last                     email
# 0  Chris  Schafer  choreymschafer@gmail.com
# 1   Mary      Doe         janedoe@email.com
# 2   John    Smith         johndoe@email.com

# %%
df1['first'] + ' ' + df1['last']
# Out:
# 0    Chris Schafer
# 1         Mary Doe
# 2       John Smith
# dtype: object

# %%
df1['full_name'] = df1['first'] + ' ' + df1['last']

df1
# Out:
#    first     last                     email      full_name
# 0  Chris  Schafer  choreymschafer@gmail.com  Chris Schafer
# 1   Mary      Doe         janedoe@email.com       Mary Doe
# 2   John    Smith         johndoe@email.com     John Smith

# %% [markdown]
# **Dropping columns**

# %%
df1.drop(columns=['first','last'], inplace = True)

# %%
df1
# Out:
#                       email      full_name
# 0  choreymschafer@gmail.com  Chris Schafer
# 1         janedoe@email.com       Mary Doe
# 2         johndoe@email.com     John Smith

# %%
df1['full_name'].str.split(' ')
# Out:
# 0    [Chris, Schafer]
# 1         [Mary, Doe]
# 2       [John, Smith]
# Name: full_name, dtype: object

# %%
df1['full_name'].str.split(' ', expand = True)
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Mary      Doe
# 2   John    Smith

# %%
df1[['first', 'last']] = df1['full_name'].str.split(' ', expand = True)

# %%
df1
# Out:
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith

# %%
#adding a single row to datraframe

df1.append({'first': 'Tony'}, ignore_index=True)
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/2916708666.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append({'first': 'Tony'}, ignore_index=True)
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3                       NaN            NaN   Tony      NaN

# %%
person2 ={"first": ["Toney", "Steve"],
          "last": ["Stark","Rogers"],
          "email": ["Toney@gmail.com", "Steve@email.com"]
    
}


df2 = pd.DataFrame(person2)

df2
# Out:
#    first    last            email
# 0  Toney   Stark  Toney@gmail.com
# 1  Steve  Rogers  Steve@email.com

# %%
df1.append(df2, ignore_index=True)
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/2149412069.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2, ignore_index=True)
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %%
df1.append(df2, ignore_index=True, sort=False)
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/2226406127.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2, ignore_index=True, sort=False)
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %%
df1= df1.append(df2, ignore_index=True, sort=False)

df1
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/3853250226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1= df1.append(df2, ignore_index=True, sort=False)
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %%
df1.drop(index = 4)
# Out:
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark

# %%
df1.drop(index=df1[df1['last'] == 'Doe'].index)
# Out:
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %%
filt = df1['last'] == 'Doe'

df1.drop(index = df1[filt].index)
# Out:
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %% [markdown]
# # Python Pandas Tutorial (Part 7): Sorting Data

# %%
df1
# Out:
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %%
df1.sort_values(by = 'last')
# Out:
#                       email      full_name  first     last
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 4           Steve@email.com            NaN  Steve   Rogers
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark

# %%
df1.sort_values(by = 'last', ascending = False)
# Out:
#                       email      full_name  first     last
# 3           Toney@gmail.com            NaN  Toney    Stark
# 2         johndoe@email.com     John Smith   John    Smith
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4           Steve@email.com            NaN  Steve   Rogers
# 1         janedoe@email.com       Mary Doe   Mary      Doe

# %%
df1.sort_values(by = ['last', 'first'], ascending = False)
# Out:
#                       email      full_name  first     last
# 3           Toney@gmail.com            NaN  Toney    Stark
# 2         johndoe@email.com     John Smith   John    Smith
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4           Steve@email.com            NaN  Steve   Rogers
# 1         janedoe@email.com       Mary Doe   Mary      Doe

# %%
df1.sort_values(by = ['last', 'first'], ascending = [False, True])
# Out:
#                       email      full_name  first     last
# 3           Toney@gmail.com            NaN  Toney    Stark
# 2         johndoe@email.com     John Smith   John    Smith
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4           Steve@email.com            NaN  Steve   Rogers
# 1         janedoe@email.com       Mary Doe   Mary      Doe

# %%
df1.sort_index()
# Out:
#                       email      full_name  first     last
# 0  choreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1         janedoe@email.com       Mary Doe   Mary      Doe
# 2         johndoe@email.com     John Smith   John    Smith
# 3           Toney@gmail.com            NaN  Toney    Stark
# 4           Steve@email.com            NaN  Steve   Rogers

# %%
df1['last'].sort_values()
# Out:
# 1        Doe
# 4     Rogers
# 0    Schafer
# 2      Smith
# 3      Stark
# Name: last, dtype: object

# %%
df.sort_values(by='Country', inplace= True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN
# 86932       Afghanistan        NaN
# 85825       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 7353        Afghanistan        NaN
# 87091       Afghanistan        NaN
# ...

# %%
df.sort_values(by = ['Country','SalaryUSD'], ascending = [True, False], inplace = True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %% [markdown]
# # Python Pandas Tutorial (Part 8): Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 28638          0.0
# 722            0.0
# 85715          NaN
# 50767          NaN
# 2782           NaN
# Name: SalaryUSD, dtype: float64

# %%
#median

df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].count()
# Out:
# 88883

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country']
# Out:
# Respondent
# 63129    Afghanistan
# 50499    Afghanistan
# 39258    Afghanistan
# 58450    Afghanistan
# 7085     Afghanistan
#             ...
# 88062            NaN
# 88076            NaN
# 88601            NaN
# 88802            NaN
# 88816            NaN
# Name: Country, Length: 88883, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
country_group = df.groupby(['Country'])

# %%
country_group.get_group('India')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# ...                                                       ...       ...
# 79312                  I am a student who is learning to code      True
# 79628                          I am a developer by profession     False
# 40151                                                     NaN     False
# 76400       I am not primarily a developer, but I write co...     False
# 30452                  I am a student who is learning to code     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df['Country'] == 'India'

df.loc[filt]
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 63129                          I am a developer by profession      True
# 50499       I am not primarily a developer, but I write co...      True
# 39258                          I am a developer by profession      True
# 58450                          I am a developer by profession      True
# 7085                           I am a developer by profession      True
# ...                                                       ...       ...
# 88062                                                     NaN     False
# 88076                                                     NaN     False
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# ...

# %%
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().head(70)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_group['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts(normalize= True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_group['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
country_group['SalaryUSD'].median().loc['India']
# Out:
# 10080.0

# %%
country_group['SalaryUSD'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
#people from India who knows Python

filt = df['Country'] == 'India'

df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 36443

# %%
# country_group['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [252], in <cell line: 1>()
# ----> 1 country_group['LanguageWorkedWith'].str.contains('Python').sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_group['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
df = pd.read_csv('survey_results_public.csv')

df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
#what percentage of people from each country know Python

country_respondents = df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())

country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python], axis = 'columns', sort = False)

python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns = {'Country': 'Numberofrespondants','LanguageWorkedWith':'numknowspython'}, inplace = True)

python_df
# Out:
#                    Numberofrespondants  numknowspython
# United States                    20949           10083
# India                             9061            3105
# Germany                           5866            2451
# United Kingdom                    5737            2384
# Canada                            3395            1558
# ...                                ...             ...
# Tonga                                1               0
# Timor-Leste                          1               1
# North Korea                          1               0
# Brunei Darussalam                    1               0
# Chad                                 1               0
#
# [179 rows x 2 columns]

# %%
python_df['PCTknowspython'] = (python_df['numknowspython']/python_df['Numberofrespondants'])*100

python_df
# Out:
#                    Numberofrespondants  numknowspython  PCTknowspython
# United States                    20949           10083       48.131176
# India                             9061            3105       34.267741
# Germany                           5866            2451       41.783157
# United Kingdom                    5737            2384       41.554820
# Canada                            3395            1558       45.891016
# ...                                ...             ...             ...
# Tonga                                1               0        0.000000
# Timor-Leste                          1               1      100.000000
# North Korea                          1               0        0.000000
# Brunei Darussalam                    1               0        0.000000
# Chad                                 1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PCTknowspython', ascending = False, inplace=True)

# %%
python_df
# Out:
#                                   Numberofrespondants  numknowspython  \
# Sao Tome and Principe                               1               1
# Timor-Leste                                         1               1
# Dominica                                            1               1
# Niger                                               1               1
# Turkmenistan                                        7               6
# ...                                               ...             ...
# Cape Verde                                          3               0
# Lao People's Democratic Republic                    3               0
# Malawi                                              2               0
# Liberia                                             2               0
# Chad                                                1               0
#
#                                   PCTknowspython
# Sao Tome and Principe                 100.000000
# ...

# %%
python_df.head()
# Out:
#                        Numberofrespondants  numknowspython  PCTknowspython
# Sao Tome and Principe                    1               1      100.000000
# Timor-Leste                              1               1      100.000000
# Dominica                                 1               1      100.000000
# Niger                                    1               1      100.000000
# Turkmenistan                             7               6       85.714286

# %%
python_df.loc['Japan']
# Out:
# Numberofrespondants    391.000000
# numknowspython         182.000000
# PCTknowspython          46.547315
# Name: Japan, dtype: float64

# %%
#what is the the most common education level of people who answered this survey

# %% [markdown]
# # Python Pandas Tutorial (Part 9): Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df1 = pd.DataFrame(people)

df1
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
#drop nulls

df1.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df1.dropna(axis='index', how= 'any')

#dropping rows if they have missing value
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df1.dropna(axis='index', how= 'all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df1.dropna(axis='columns', how= 'all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df1.dropna(axis='columns', how= 'any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df1.dropna(axis = 'index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df1.dropna(axis = 'index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df1.dropna(axis = 'index', how='any', subset=['last', 'email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df1.replace('NA', np.nan,inplace = True)
df1.replace('Missing', np.nan,inplace = True)

df1
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df1.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df1.dropna(axis = 'index', how='any', subset=['last', 'email'])
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df1.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df1.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df1.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
#CASTING DATA TYPES

df1['age']
# Out:
# 0      33
# 1      55
# 2      63
# 3      36
# 4    None
# 5    None
# 6     NaN
# Name: age, dtype: object

# %%
df1.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
#df1['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [294], in <cell line: 1>()
# ----> 1 df1['age'].mean()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:11127, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11109 @doc(
#   11110     _num_doc,
#   11111     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11125     **kwargs,
#   11126 ):
# > 11127     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:10697, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10689 def mean(
#   10690     self,
#   10691     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
# ...

# %%
#df1['age'] = df1['age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [295], in <cell line: 1>()
# ----> 1 df1['age'] = df1['age'].astype(int)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:5920, in NDFrame.astype(self, dtype, copy, errors)
#    5913     results = [
#    5914         self.iloc[:, i].astype(dtype, copy=copy)
#    5915         for i in range(len(self.columns))
#    5916     ]
#    5918 else:
#    5919     # else, only a single dtype is given
# -> 5920     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5921     return self._constructor(new_data).__finalize__(self, method="astype")
#    5923 # GH 33113: handle empty frame or series
#
# ...

# %%
df1['age'] = df1['age'].astype(float)

# %%
df1.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df1['age'].mean()
# Out:
# 46.75

# %%
na_vals = ['NA','Missing']
df = pd.read_csv('survey_results_public.csv', index_col='Respondent', na_values = na_vals)

df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['YearsCode'].head(80)
# Out:
# Respondent
# 1                    4
# 2                  NaN
# 3                    3
# 4                    3
# 5                   16
# 6                   13
# 7                    6
# 8                    8
# 9                   12
# 10                  12
# 11                   2
# 12                   5
# 13                  17
# 14                  13
# 15                   3
# 16                  10
# 17                   5
# 18                  10
# 19                  14
# 20                   8
# 21                   5
# 22                  35
# 23                   3
# 24                   2
# 25                   2
# 26                  12
# 27                   7
# 28                  10
# 29                   4
# 30                   6
# 31    Less than 1 year
# 32                   3
# 33                   6
# 34    Less than 1 year
# 35                  14
# 36                  10
# 37                   7
# 38                  30
# 39                  30
# ...

# %%
# df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [301], in <cell line: 1>()
# ----> 1 df['YearsCode'].mean()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:11127, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11109 @doc(
#   11110     _num_doc,
#   11111     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11125     **kwargs,
#   11126 ):
# > 11127     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:10697, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10689 def mean(
#   10690     self,
#   10691     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
# ...

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [302], in <cell line: 1>()
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:5920, in NDFrame.astype(self, dtype, copy, errors)
#    5913     results = [
#    5914         self.iloc[:, i].astype(dtype, copy=copy)
#    5915         for i in range(len(self.columns))
#    5916     ]
#    5918 else:
#    5919     # else, only a single dtype is given
# -> 5920     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5921     return self._constructor(new_data).__finalize__(self, method="astype")
#    5923 # GH 33113: handle empty frame or series
#
# ...

# %%
filt = df['YearsCode'] =='Less than 1 year'

df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 31          I am a student who is learning to code       No
# 34          I am a student who is learning to code      Yes
# 309         I am a student who is learning to code      Yes
# 369         I am a student who is learning to code      Yes
# 380                 I am a developer by profession       No
# ...                                            ...      ...
# 77618                                          NaN      Yes
# 78266                                          NaN       No
# 78741                                          NaN      Yes
# 81922                                          NaN      Yes
# 82717                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 31                                                      Never
# 34                                                      Never
# ...

# %%
#df.loc[filt].value_counts()

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace = True)
df['YearsCode'].replace('More than 50 years', 51, inplace = True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# # Python Pandas Tutorial (Part 10): Working with Dates and Time Series Data

# %%
df3 = pd.read_csv('ETH_1h.csv')

df3.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df3.shape
# Out:
# (23674, 7)

# %%
df3.loc[0, 'Date']
# Out:
# '2020-03-13 08-PM'

# %%
#df3.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [315], in <cell line: 1>()
# ----> 1 df3.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
#df3['Date'] = pd.to_datetime(df3['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df3['Date'] = pd.to_datetime(df3['Date'], format='%Y-%m-%d %I-%p')

# %%
df3['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df3.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
d_parser = lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
df3 = pd.read_csv('ETH_1h.csv',parse_dates=['Date'], date_parser = d_parser)

df3.head()
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/163416636.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df3['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df3['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df3['dayofweek'] = df3['Date'].dt.day_name()

df3
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       dayofweek
# ...

# %%
df3['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df3['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df3['Date'].max() - df3['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df3['Date'] >= '2020')

df3.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       dayofweek
# 0        Friday
# ...

# %%
filt = (df3['Date'] >= '2019') & (df3['Date'] < '2020')

df3.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       dayofweek
# ...

# %%
filt = (df3['Date'] >= pd.to_datetime('2019-01-01')) & (df3['Date'] < pd.to_datetime('2020-01-01'))

df3.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       dayofweek
# ...

# %%
df3.set_index('Date', inplace=True)

# %%
df3['2019']
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/3359826300.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df3['2019']
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# ...

# %%
df3['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      dayofweek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df3['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df3['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df3['2020-01':'2020-02'].head(24)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41
# 2020-02-29 12:00:00  ETHUSD  226.50  226.50  224.14  225.29   359022.09
# ...

# %%
df3['2020-01-01']['High']
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/3573748417.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df3['2020-01-01']['High']
# Date
# 2020-01-01 23:00:00    130.27
# 2020-01-01 22:00:00    131.41
# 2020-01-01 21:00:00    131.99
# 2020-01-01 20:00:00    131.87
# 2020-01-01 19:00:00    131.72
# 2020-01-01 18:00:00    132.14
# 2020-01-01 17:00:00    132.68
# 2020-01-01 16:00:00    132.56
# 2020-01-01 15:00:00    132.15
# 2020-01-01 14:00:00    132.05
# 2020-01-01 13:00:00    132.08
# 2020-01-01 12:00:00    131.31
# 2020-01-01 11:00:00    131.42
# 2020-01-01 10:00:00    130.33
# 2020-01-01 09:00:00    130.22
# 2020-01-01 08:00:00    130.01
# 2020-01-01 07:00:00    130.25
# 2020-01-01 06:00:00    130.25
# 2020-01-01 05:00:00    129.94
# 2020-01-01 04:00:00    130.00
# ...

# %%
df3['2020-01-01']['High'].max()
# Out:
# /var/folders/5n/plkx587s0kj_92g0r6z1vvq40000gn/T/ipykernel_86471/761621772.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df3['2020-01-01']['High'].max()
# 132.68

# %%
df3['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs = df3['High'].resample('D').max()

highs['2020-01-01']
# Out:
# 132.68

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df3['High'].resample('W').max()
# Out:
# Date
# 2017-07-02    293.73
# 2017-07-09    285.00
# 2017-07-16    240.33
# 2017-07-23    249.40
# 2017-07-30    229.99
#                ...
# 2020-02-16    290.00
# 2020-02-23    287.13
# 2020-03-01    278.13
# 2020-03-08    253.01
# 2020-03-15    208.65
# Freq: W-SUN, Name: High, Length: 142, dtype: float64

# %%
df3.resample('W').agg({'Close':'mean','High':'max', 'Low': 'min'})
# Out:
#                  Close    High     Low
# Date
# 2017-07-02  268.202162  293.73  253.23
# 2017-07-09  261.062083  285.00  231.25
# 2017-07-16  195.698393  240.33  130.26
# 2017-07-23  212.783750  249.40  153.25
# 2017-07-30  203.309524  229.99  178.03
# ...                ...     ...     ...
# 2020-02-16  255.198452  290.00  216.31
# 2020-02-23  265.321905  287.13  242.36
# 2020-03-01  236.373988  278.13  209.26
# 2020-03-08  229.817619  253.01  196.00
# 2020-03-15  176.332821  208.65   90.00
#
# [142 rows x 3 columns]

# %% [markdown]
# # Python Pandas Tutorial (Part 11): Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = df['Country'] == 'India'

india_df = df.loc[filt]

india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
#exporting data

india_df.to_csv('modifed_india_df.csv')

# %%
india_df.to_csv('modifed_india_df.tsv', sep='\t')

# %%
india_df_new = pd.read_csv('modifed_india_df.tsv',sep='\t')

# %%
india_df_new.head()
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           8             I code primarily as a hobby      Yes
# 1          10          I am a developer by profession      Yes
# 2          15  I am a student who is learning to code      Yes
# 3          50          I am a developer by profession      Yes
# 4          65          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                                NaN
#
#                            Employment Country         Student  \
# ...

# %%
# !pip install xlwt openpyxl xlrd

# %%
# !pip3 install openpyxl
# Out:
# ...
#      |████████████████████████████████| 245kB 3.9MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.2.3, however version 22.0.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
india_df.to_excel('modifed_india_df.xlsx')

# %%
india_df_Excel = pd.read_excel('modifed_india_df.xlsx', index_col='Respondent')

# %%
india_df_Excel.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_json('modifed_india_df.json')

# %%
india_df.to_json('modifed_india_df.json', orient='records', lines=True)

# %%
india_df_json = pd.read_json('modifed_india_df.json', orient='records', lines=True)

india_df_json.head()
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
# 3          I am a developer by profession      Yes
# 4          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# ...

# %%
# !pip3 install SQLAlchemy
# Out:
# ...
#      |████████████████████████████████| 1.5MB 4.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 102kB 24.2MB/s ta 0:00:01
# ...
# WARNING: You are using pip version 19.2.3, however version 22.0.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip3 install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 2.2MB 4.6MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.2.3, however version 22.0.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
#engine = create_engine('postgresql://dbusers:dbpass@localhost:5432/sample_db')

# %%
#india_df.to_sql('sample_table', engine, if_exist='replace')

# %%
#sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
sql_df = pd.read_sql_query('select * From sample_table', engine, index_col='Respondent')
